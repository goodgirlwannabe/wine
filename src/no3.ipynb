# %% [markdown]
# # No 3
# Menentukan setiap kolom numerik berdistribusi normal atau tidak. Gunakan normality test
# yang dikaitkan dengan histogram plot.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sp
import seaborn as sns

df = pd.read_csv('anggur.csv')
df
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             5.90            0.4451       0.1813        2.049401   0.070574
# 1             8.40            0.5768       0.2099        3.109590   0.101681
# 2             7.54            0.5918       0.3248        3.673744   0.072416
# 3             5.39            0.4201       0.3131        3.371815   0.072755
# 4             6.51            0.5675       0.1940        4.404723   0.066379
# ..             ...               ...          ...             ...        ...
# 995           7.96            0.6046       0.2662        1.592048   0.057555
# 996           8.48            0.4080       0.2227        0.681955   0.051627
# 997           6.11            0.4841       0.3720        2.377267   0.042806
# 998           7.76            0.3590       0.3208        4.294486   0.098276
# 999           5.87            0.5214       0.1883        2.179490   0.052923
#
# ...

# %% [markdown]
# Normality test dapat dilakukan dengan melakukan pemanggilan fungsi normaltest dari library scipy. Implementasi test ini berdasar pada D'Agostino-Pearson Test yang juga sering disebut sebagai Omnibus D'Agostino.
#
# D'Agostino-Pearson Test merupakan salah satu metode untuk menguji normalitas sampel data. Data dihitung berdasarkan skewness dan kurtosis data.
#
# Perhitungan D'Agostino-Pearson Test dapat menggunakan rumus berikut.
# $$K^2 = Z_{s}^2 + Z_{k}^2 $$
#
#
# $ Z_{s}^2 $ merupakan Z-score skewness dan $ Z_{k}^2 $ merupakan Z-score kurtosis. Apabila hipotesis nol terbukti, $K^2$ dapat diaproksimasi terdistribusi chi-squared dengan derajat kebebasan 2.
#
# Hipotesis nol $H_{0}$ merupakan data yang berasal dari populasi dengan distribusi normal. $H_{0}$ dapat diuji dengan membandingkan nilai $ \alpha $ yang ditetapkan dengan p-value yang didapat dari normaltest. $H_{0}$ diterima ketika p-value lebih kecil dari $ \alpha $.
#
# Untuk mempermudah pembuktian hasil normality test, ditampilkan histogram distribusi data dengan memanggil fungsi histplot yang diimport dari library seaborn.

# %% [markdown]
# # Fixed Acidity

# %%
stat, p = sp.normaltest(df['fixed acidity'])
a = 0.05
print(f"Nilai p ialah: {p}")
if p < a:
        print('Hipotesis nol ditolak, data fixed acidity tidak berdistribusi normal')
else:
        print('Hipotesis nol diterima, data fixed acidity berdistribusi normal')
sns.histplot(df['fixed acidity'])
plt.show()
# Out:
# Nilai p ialah: 0.9308584274486692
# Hipotesis nol diterima, data fixed acidity berdistribusi normal

# %% [markdown]
# # Volatite Acidity

# %%
stat, p = sp.normaltest(df['volatile acidity'])
a = 0.05
print(f"Nilai p ialah: {p}")
if p < a:
        print('Hipotesis nol ditolak, data volatile acidity tidak berdistribusi normal')
else:
        print('Hipotesis nol diterima, data volatile acidity berdistribusi normal')
sns.histplot(df['volatile acidity'])
plt.show()
# Out:
# Nilai p ialah: 0.022581461594113835
# Hipotesis nol ditolak, data volatile acidity tidak berdistribusi normal

# %% [markdown]
# # Citric Acid

# %%
stat, p = sp.normaltest(df['citric acid'])
a = 0.05
print(f"Nilai p ialah: {p}")
if p < a:
        print('Hipotesis nol ditolak, data citric acid tidak berdistribusi normal')
else:
        print('Hipotesis nol diterima, data citric acid berdistribusi normal')
sns.histplot(df['citric acid'])
plt.show()
# Out:
# Nilai p ialah: 0.6816899375976969
# Hipotesis nol diterima, data citric acid berdistribusi normal

# %% [markdown]
# # Residual Sugar

# %%
stat, p = sp.normaltest(df['residual sugar'])
a = 0.05
print(f"Nilai p ialah: {p}")
if p < a:
        print('Hipotesis nol ditolak, data residual sugar tidak berdistribusi normal')
else:
        print('Hipotesis nol diterima, data residual sugar berdistribusi normal')
sns.histplot(df['residual sugar'])
plt.show()
# Out:
# Nilai p ialah: 0.2246670332131056
# Hipotesis nol diterima, data residual sugar berdistribusi normal

# %% [markdown]
# # Chlorides

# %%
stat, p = sp.normaltest(df['chlorides'])
a = 0.05
print(f"Nilai p ialah: {p}")
if p < a:
        print('Hipotesis nol ditolak, data chlorides tidak berdistribusi normal')
else:
        print('Hipotesis nol diterima, data chlorides berdistribusi normal')
sns.histplot(df['chlorides'])
plt.show()
# Out:
# Nilai p ialah: 0.17048274704296862
# Hipotesis nol diterima, data chlorides berdistribusi normal

# %% [markdown]
# # Free Sulfur Dioxide

# %%
stat, p = sp.normaltest(df['free sulfur dioxide'])
a = 0.05
print(f"Nilai p ialah: {p}")
if p < a:
        print('Hipotesis nol ditolak, data free sulfur dioxide tidak berdistribusi normal')
else:
        print('Hipotesis nol diterima, data free sulfur dioxide berdistribusi normal')
sns.histplot(df['free sulfur dioxide'])
plt.show()
# Out:
# Nilai p ialah: 0.01743043451827735
# Hipotesis nol ditolak, data free sulfur dioxide tidak berdistribusi normal

# %% [markdown]
# # Total Sulfur Dioxide

# %%
stat, p = sp.normaltest(df['total sulfur dioxide'])
a = 0.05
print(f"Nilai p ialah: {p}")
if p < a:
        print('Hipotesis nol ditolak, data total sulfur dioxide tidak berdistribusi normal')
else:
        print('Hipotesis nol diterima, data total sulfur dioxide berdistribusi normal')
sns.histplot(df['total sulfur dioxide'])
plt.show()
# Out:
# Nilai p ialah: 0.8488846101395726
# Hipotesis nol diterima, data total sulfur dioxide berdistribusi normal

# %% [markdown]
# # Density

# %%
stat, p = sp.normaltest(df['density'])
a = 0.05
print(f"Nilai p ialah: {p}")
if p < a:
        print('Hipotesis nol ditolak, data density tidak berdistribusi normal')
else:
        print('Hipotesis nol diterima, data density berdistribusi normal')
sns.histplot(df['density'])
plt.show()
# Out:
# Nilai p ialah: 0.5985227325531981
# Hipotesis nol diterima, data density berdistribusi normal

# %% [markdown]
# # pH

# %%
stat, p = sp.normaltest(df['pH'])
a = 0.05
print(f"Nilai p ialah: {p}")
if p < a:
        print('Hipotesis nol ditolak, data pH tidak berdistribusi normal')
else:
        print('Hipotesis nol diterima, data pH berdistribusi normal')
sns.histplot(df['pH'])
plt.show()
# Out:
# Nilai p ialah: 0.13678740824860436
# Hipotesis nol diterima, data pH berdistribusi normal

# %% [markdown]
# # Sulphates

# %%
stat, p = sp.normaltest(df['sulphates'])
a = 0.05
print(f"Nilai p ialah: {p}")
if p < a:
        print('Hipotesis nol ditolak, data sulphates tidak berdistribusi normal')
else:
        print('Hipotesis nol diterima, data sulphates berdistribusi normal')
sns.histplot(df['sulphates'])
plt.show()
# Out:
# Nilai p ialah: 0.13884318628391681
# Hipotesis nol diterima, data sulphates berdistribusi normal

# %% [markdown]
# # Alcohol

# %%
stat, p = sp.normaltest(df['alcohol'])
a = 0.05
print(f"Nilai p ialah: {p}")
if p < a:
        print('Hipotesis nol ditolak, data alcohol tidak berdistribusi normal')
else:
        print('Hipotesis nol diterima, data alcohol berdistribusi normal')
sns.histplot(df['alcohol'])
plt.show()
# Out:
# Nilai p ialah: 0.6790884901361043
# Hipotesis nol diterima, data alcohol berdistribusi normal

# %% [markdown]
# # Quality

# %%
stat, p = sp.normaltest(df['quality'])
a = 0.05
print(f"Nilai p ialah: {p}")
if p < a:
        print('Hipotesis nol ditolak, data quality tidak berdistribusi normal')
else:
        print('Hipotesis nol diterima, data quality berdistribusi normal')
sns.histplot(df['quality'])
plt.show()
# Out:
# Nilai p ialah: 0.3888139394184818
# Hipotesis nol diterima, data quality berdistribusi normal
