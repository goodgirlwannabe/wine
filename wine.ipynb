# %%
import pandas as pd
df = pd.read_csv('anggur.csv')
df
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             5.90            0.4451       0.1813        2.049401   0.070574
# 1             8.40            0.5768       0.2099        3.109590   0.101681
# 2             7.54            0.5918       0.3248        3.673744   0.072416
# 3             5.39            0.4201       0.3131        3.371815   0.072755
# 4             6.51            0.5675       0.1940        4.404723   0.066379
# ..             ...               ...          ...             ...        ...
# 995           7.96            0.6046       0.2662        1.592048   0.057555
# 996           8.48            0.4080       0.2227        0.681955   0.051627
# 997           6.11            0.4841       0.3720        2.377267   0.042806
# 998           7.76            0.3590       0.3208        4.294486   0.098276
# 999           5.87            0.5214       0.1883        2.179490   0.052923
#
# ...

# %% [markdown]
# # Total Sulfur Dioxide

# %%
# 7 Total Sulfur Dioxide
# Mean
meanTotalSulfurDioxide = df['total sulfur dioxide'].mean()
print ("Mean Total Sulfur Dioxide: ", meanTotalSulfurDioxide)

# Median
medianTotalSulfurDioxide = df['total sulfur dioxide'].median()
print ("Median Total Sulfur Dioxide: ", medianTotalSulfurDioxide)

# Mode
modusTotalSulfurDioxide = df['total sulfur dioxide'].mode()
print ("Modus Total Sulfur Dioxide: ", modusTotalSulfurDioxide)

# Standar Deviasi
standarDeviasiTotalSulfurDioxide = df['total sulfur dioxide'].std()
print ("Standar Deviasi Total Sulfur Dioxide: ", standarDeviasiTotalSulfurDioxide)

# Variance
varianceTotalSulfurDioxide = df['total sulfur dioxide'].var()
print ("Variance Total Sulfur Dioxide: ", varianceTotalSulfurDioxide)

# Range
rangeTotalSulfurDioxide = df['total sulfur dioxide'].max() - df['total sulfur dioxide'].min()
print ("Range Total Sulfur Dioxide: ", rangeTotalSulfurDioxide)

# Minimum
minimumTotalSulfurDioxide = df['total sulfur dioxide'].min()
print ("Minimum Total Sulfur Dioxide: ", minimumTotalSulfurDioxide)

# Maximum
maximumTotalSulfurDioxide = df['total sulfur dioxide'].max()
print ("Maximum Total Sulfur Dioxide: ", maximumTotalSulfurDioxide)

# Quartile
quartileTotalSulfurDioxide = df['total sulfur dioxide'].quantile([0.25,0.5,0.75])
print ("Quartile Total Sulfur Dioxide: ")
print ("     1. Kuartil 25%: ", quartileTotalSulfurDioxide[0.25])
print ("     2. Kuartil 50%: ", quartileTotalSulfurDioxide[0.5])
print ("     3. Kuartil 75%: ", quartileTotalSulfurDioxide[0.75])

# IQR
IQRTotalSulfurDioxide = quartileTotalSulfurDioxide[0.75] - quartileTotalSulfurDioxide[0.25]
print ("IQR Total Sulfur Dioxide: ", IQRTotalSulfurDioxide)

# Skewness
skewnessTotalSulfurDioxide = df['total sulfur dioxide'].skew()
print ("Skewness Total Sulfur Dioxide: ", skewnessTotalSulfurDioxide)

# Kurtosis
kurtosisTotalSulfurDioxide = df['total sulfur dioxide'].kurt()
print ("Kurtosis Total Sulfur Dioxide: ", kurtosisTotalSulfurDioxide)
# Out:
# Mean Total Sulfur Dioxide:  40.290150000000004
# Median Total Sulfur Dioxide:  40.19
# Modus Total Sulfur Dioxide:  0    35.20
# 1    37.25
# 2    39.64
# 3    40.61
# 4    41.05
# 5    41.59
# 6    44.51
# Name: total sulfur dioxide, dtype: float64
# Standar Deviasi Total Sulfur Dioxide:  9.965767376218295
# Variance Total Sulfur Dioxide:  99.3165193968969
# Range Total Sulfur Dioxide:  66.80999999999999
# Minimum Total Sulfur Dioxide:  3.15
# Maximum Total Sulfur Dioxide:  69.96
# Quartile Total Sulfur Dioxide:
#      1. Kuartil 25%:  33.785
#      2. Kuartil 50%:  40.19
#      3. Kuartil 75%:  47.0225
# IQR Total Sulfur Dioxide:  13.237500000000004
# Skewness Total Sulfur Dioxide:  -0.024060026812269975
# Kurtosis Total Sulfur Dioxide:  0.06394978916172311

# %% [markdown]
# # Density

# %%
# 8 Density

# Mean
meanDensity = df['density'].mean()
print ("Mean Density: ", meanDensity)

# Median
medianDensity = df['density'].median()
print ("Median Density: ", medianDensity)

# Mode
modusDensity = df['density'].mode()
print ("Modus Density: ", modusDensity)

# Standar Deviasi
standarDeviasiDensity = df['density'].std()
print ("Standar Deviasi Density: ", standarDeviasiDensity)

# Variance
varianceDensity = df['density'].var()
print ("Variance Density: ", varianceDensity)

# Range
rangeDensity = df['density'].max() - df['density'].min()
print ("Range Density: ", rangeDensity)

# Minimum
minimumDensity = df['density'].min()
print ("Minimum Density: ", minimumDensity)

# Maximum
maximumDensity = df['density'].max()
print ("Maximum Density: ", maximumDensity)

# Quartile
quartileDensity = df['density'].quantile([0.25,0.5,0.75])
print ("Quartile Density: ")
print("     1. Kuartil 25%: ", quartileDensity[0.25])
print("     2. Kuartil 50%: ", quartileDensity[0.5])
print("     3. Kuartil 75%: ", quartileDensity[0.75])

# IQR
IQRDensity = quartileDensity[0.75] - quartileDensity[0.25]
print ("IQR Density: ", IQRDensity)

# Skewness
skewnessDensity = df['density'].skew()
print ("Skewness Density: ", skewnessDensity)

# Kurtosis
kurtosisDensity = df['density'].kurt()
print ("Kurtosis Density: ", kurtosisDensity)

# %% [markdown]
# # pH

# %%
# 9 pH

# Mean
meanpH = df['pH'].mean()
print ("Mean pH: ", meanpH)

# Median
medianpH = df['pH'].median()
print ("Median pH: ", medianpH)

# Mode
moduspH = df['pH'].mode()
print ("Modus pH: ", moduspH)

# Standar Deviasi
standarDeviasiPh = df['pH'].std()
print ("Standar Deviasi pH: ", standarDeviasiPh)

# Variance
variancepH = df['pH'].var()
print ("Variance pH: ", variancepH)

# Range
rangepH = df['pH'].max() - df['pH'].min()
print ("Range pH: ", rangepH)

# Minimum
minimumpH = df['pH'].min()
print ("Minimum pH: ", minimumpH)

# Maximum
maximumpH = df['pH'].max()
print ("Maximum pH: ", maximumpH)

# Quartile
quartilepH = df['pH'].quantile([0.25,0.5,0.75])
print ("Quartile pH: ")
print("     1. Kuartil 25%: ", quartilepH[0.25])
print("     2. Kuartil 50%: ", quartilepH[0.5])
print("     3. Kuartil 75%: ", quartilepH[0.75])

# IQR
IQRpH = quartilepH[0.75] - quartilepH[0.25]
print ("IQR pH: ", IQRpH)

# Skewness
skewnesspH = df['pH'].skew()
print ("Skewness pH: ", skewnesspH)

# Kurtosis
kurtosispH = df['pH'].kurt()
print ("Kurtosis pH: ", kurtosispH)

# %% [markdown]
# # Sulphates

# %%
# 10 Sulphates

# Mean
meanSulphates = df['sulphates'].mean()
print ("Mean Sulphates: ", meanSulphates)

# Median
medianSulphates = df['sulphates'].median()
print ("Median Sulphates: ", medianSulphates)

# Mode
modusSulphates = df['sulphates'].mode()
print ("Modus Sulphates: ", modusSulphates)

# Standar Deviasi
standarDeviasiSulphates = df['sulphates'].std()
print ("Standar Deviasi Sulphates: ", standarDeviasiSulphates)

# Variance
varianceSulphates = df['sulphates'].var()
print ("Variance Sulphates: ", varianceSulphates)

# Range
rangeSulphates = df['sulphates'].max() - df['sulphates'].min()
print ("Range Sulphates: ", rangeSulphates)

# Minimum
minimumSulphates = df['sulphates'].min()
print ("Minimum Sulphates: ", minimumSulphates)

# Maximum
maximumSulphates = df['sulphates'].max()
print ("Maximum Sulphates: ", maximumSulphates)

# Quartile
quartileSulphates = df['sulphates'].quantile([0.25,0.5,0.75])
print ("Quartile Sulphates: ")
print("     1. Kuartil 25%: ", quartileSulphates[0.25])
print("     2. Kuartil 50%: ", quartileSulphates[0.5])
print("     3. Kuartil 75%: ", quartileSulphates[0.75])

# IQR
IQRSulphates = quartileSulphates[0.75] - quartileSulphates[0.25]
print ("IQR Sulphates: ", IQRSulphates)

# Skewness
skewnessSulphates = df['sulphates'].skew()
print ("Skewness Sulphates: ", skewnessSulphates)

# Kurtosis
kurtosisSulphates = df['sulphates'].kurt()
print ("Kurtosis Sulphates: ", kurtosisSulphates)

# %% [markdown]
# # Alcohol

# %%
# 11 Alcohol

# Mean
meanAlcohol = df['alcohol'].mean()
print ("Mean Alcohol: ", meanAlcohol)

# Median
medianAlcohol = df['alcohol'].median()
print ("Median Alcohol: ", medianAlcohol)

# Mode
modusAlcohol = df['alcohol'].mode()
print ("Modus Alcohol: ", modusAlcohol)

# Standar Deviasi
standarDeviasiAlcohol = df['alcohol'].std()
print ("Standar Deviasi Alcohol: ", standarDeviasiAlcohol)

# Variance
varianceAlcohol = df['alcohol'].var()
print ("Variance Alcohol: ", varianceAlcohol)

# Range
rangeAlcohol = df['alcohol'].max() - df['alcohol'].min()
print ("Range Alcohol: ", rangeAlcohol)

# Minimum
minimumAlcohol = df['alcohol'].min()
print ("Minimum Alcohol: ", minimumAlcohol)

# Maximum
maximumAlcohol = df['alcohol'].max()
print ("Maximum Alcohol: ", maximumAlcohol)

# Quartile
quartileAlcohol = df['alcohol'].quantile([0.25,0.5,0.75])
print ("Quartile Alcohol: ")
print("     1. Kuartil 25%: ", quartileAlcohol[0.25])
print("     2. Kuartil 50%: ", quartileAlcohol[0.5])
print("     3. Kuartil 75%: ", quartileAlcohol[0.75])

# IQR
IQROlcohol = quartileAlcohol[0.75] - quartileAlcohol[0.25]
print ("IQR Alcohol: ", IQROlcohol)

# Skewness
skewnessAlcohol = df['alcohol'].skew()
print ("Skewness Alcohol: ", skewnessAlcohol)

# Kurtosis
kurtosisAlcohol = df['alcohol'].kurt()
print ("Kurtosis Alcohol: ", kurtosisAlcohol)

# %% [markdown]
# # Quality

# %%
# 12 Quality

# Mean
meanQuality = df['quality'].mean()
print ("Mean Quality: ", meanQuality)

# Median
medianQuality = df['quality'].median()
print ("Median Quality: ", medianQuality)

# Mode
modusQuality = df['quality'].mode()
print ("Modus Quality: ", modusQuality)

# Standar Deviasi
standarDeviasiQuality = df['quality'].std()
print ("Standar Deviasi Quality: ", standarDeviasiQuality)

# Variance
varianceQuality = df['quality'].var()
print ("Variance Quality: ", varianceQuality)

# Range
rangeQuality = df['quality'].max() - df['quality'].min()
print ("Range Quality: ", rangeQuality)

# Minimum
minimumQuality = df['quality'].min()
print ("Minimum Quality: ", minimumQuality)

# Maximum
maximumQuality = df['quality'].max()
print ("Maximum Quality: ", maximumQuality)

# Quartile
quartileQuality = df['quality'].quantile([0.25,0.5,0.75])
print ("Quartile Quality: ")
print("     1. Kuartil 25%: ", quartileQuality[0.25])
print("     2. Kuartil 50%: ", quartileQuality[0.5])
print("     3. Kuartil 75%: ", quartileQuality[0.75])

# IQR
IQRQuality = quartileQuality[0.75] - quartileQuality[0.25]
print ("IQR Quality: ", IQRQuality)

# Skewness
skewnessQuality = df['quality'].skew()
print ("Skewness Quality: ", skewnessQuality)

# Kurtosis
kurtosisQuality = df['quality'].kurt()
print ("Kurtosis Quality: ", kurtosisQuality)
# Out:
# Mean Quality:  7.958
# Median Quality:  8.0
# Modus Quality:  0    8
# Name: quality, dtype: int64
# Standar Deviasi Quality:  0.9028017783827471
# Variance Quality:  0.8150510510510509
# Range Quality:  5
# Minimum Quality:  5
# Maximum Quality:  10
# Quartile Quality:
#      1. Kuartil 25%:  7.0
#      2. Kuartil 50%:  8.0
#      3. Kuartil 75%:  9.0
# IQR Quality:  2.0
# Skewness Quality:  -0.08905409122491781
# Kurtosis Quality:  0.10829100232871003
