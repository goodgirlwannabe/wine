# %%
import pandas as pd
df = pd.read_csv('anggur.csv')
df
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             5.90            0.4451       0.1813        2.049401   0.070574
# 1             8.40            0.5768       0.2099        3.109590   0.101681
# 2             7.54            0.5918       0.3248        3.673744   0.072416
# 3             5.39            0.4201       0.3131        3.371815   0.072755
# 4             6.51            0.5675       0.1940        4.404723   0.066379
# ..             ...               ...          ...             ...        ...
# 995           7.96            0.6046       0.2662        1.592048   0.057555
# 996           8.48            0.4080       0.2227        0.681955   0.051627
# 997           6.11            0.4841       0.3720        2.377267   0.042806
# 998           7.76            0.3590       0.3208        4.294486   0.098276
# 999           5.87            0.5214       0.1883        2.179490   0.052923
#
# ...

# %% [markdown]
# # No 1
# Menulis deskripsi statistika (Descriptive Statistics) dari semua kolom pada data yang bersifat
# numerik, terdiri dari mean, median, modus, standar deviasi, variansi, range, nilai minimum,
# maksimum, kuartil, IQR, skewness dan kurtosis. Boleh juga ditambahkan deskripsi lain.

# %% [markdown]
# # Fixed Acidity

# %%
# mean
meanFixedAcid = df['fixed acidity'].mean()
print("Rata-rata nilai fixed acidity adalah", meanFixedAcid)

# median
medianFixedAcid = df['fixed acidity'].median()
print("Median nilai fixed acidity adalah", medianFixedAcid)

#modus
modusFixedAcid = df['fixed acidity'].mode()
print("Modus nilai fixed acidity adalah", modusFixedAcid)

# standard deviation
stdFixedAcid = df['fixed acidity'].std()
print("Standar deviasi nilai fixed acidity adalah", stdFixedAcid)

# variance
varFixedAcid = df['fixed acidity'].var()
print("Variansi nilai fixed acidity adalah", varFixedAcid)

# range
rangeFixedAcid = df['fixed acidity'].max() - df['fixed acidity'].min()
print("Range nilai fixed acidity adalah", rangeFixedAcid)

# minimum
minFixedAcid = df['fixed acidity'].min()
print("Nilai minimum fixed acidity adalah", minFixedAcid)

# maximum
maxFixedAcid = df['fixed acidity'].max()
print("Nilai maximum fixed acidity adalah", maxFixedAcid)

# kuartil
quartileFixedAcid25 = df['fixed acidity'].quantile(0.25)
quartileFixedAcid50 = df['fixed acidity'].quantile(0.50)
quartileFixedAcid75 = df['fixed acidity'].quantile(0.75)
print("Kuartil nilai fixed acidity: ")
print("     1. Kuartil 25% adalah", quartileFixedAcid25)
print("     2. Kuartil 50% adalah", quartileFixedAcid50)
print("     3. Kuartil 75% adalah", quartileFixedAcid75)

# interquartile range
iqrFixedAcid = quartileFixedAcid75 - quartileFixedAcid25
print("Interquartile range nilai fixed acidity adalah", iqrFixedAcid)

# skewness
skewFixedAcid = df['fixed acidity'].skew()
print("Skewness nilai fixed acidity adalah", skewFixedAcid)

# kurtosis
kurtFixedAcid = df['fixed acidity'].kurt()
print("Kurtosis nilai fixed acidity adalah", kurtFixedAcid)
# Out:
# Rata-rata nilai fixed acidity adalah 7.15253
# Median nilai fixed acidity adalah 7.15
# Modus nilai fixed acidity adalah 0    6.54
# Name: fixed acidity, dtype: float64
# Standar deviasi nilai fixed acidity adalah 1.2015975764938258
# Variansi nilai fixed acidity adalah 1.4438367358358357
# Range nilai fixed acidity adalah 8.17
# Nilai minimum fixed acidity adalah 3.32
# Nilai maximum fixed acidity adalah 11.49
# Kuartil nilai fixed acidity:
#      1. Kuartil 25% adalah 6.3774999999999995
#      2. Kuartil 50% adalah 7.15
#      3. Kuartil 75% adalah 8.0
# Interquartile range nilai fixed acidity adalah 1.6225000000000005
# Skewness nilai fixed acidity adalah -0.028878575532660055
# Kurtosis nilai fixed acidity adalah -0.019292120932933532

# %% [markdown]
# # Volatile Acidity

# %%
# mean
meanVolatileAcid = df['volatile acidity'].mean()
print("Rata-rata nilai volatile acidity adalah", meanVolatileAcid)

# median
medianVolatileAcid = df['volatile acidity'].median()
print("Median nilai volatile acidity adalah", medianVolatileAcid)

#modus
modusVolatileAcid = df['volatile acidity'].mode()
print("Modus nilai volatile acidity adalah", modusVolatileAcid)

# standard deviation
stdVolatileAcid = df['volatile acidity'].std()
print("Standar deviasi nilai volatile acidity adalah", stdVolatileAcid)

# variance
varVolatileAcid = df['volatile acidity'].var()
print("Variansi nilai volatile acidity adalah", varVolatileAcid)

# range
rangeVolatileAcid = df['volatile acidity'].max() - df['volatile acidity'].min()
print("Range nilai volatile acidity adalah", rangeVolatileAcid)

# minimum
minVolatileAcid = df['volatile acidity'].min()
print("Nilai minimum volatile acidity adalah", minVolatileAcid)

# maximum
maxVolatileAcid = df['volatile acidity'].max()
print("Nilai maximum volatile acidity adalah", maxVolatileAcid)

# kuartil
quartileVolatileAcid25 = df['volatile acidity'].quantile(0.25)
quartileVolatileAcid50 = df['volatile acidity'].quantile(0.50)
quartileVolatileAcid75 = df['volatile acidity'].quantile(0.75)
print("Kuartil nilai volatile acidity: ")
print("     1. Kuartil 25% adalah", quartileVolatileAcid25)
print("     2. Kuartil 50% adalah", quartileVolatileAcid50)
print("     3. Kuartil 75% adalah", quartileVolatileAcid75)

# interquartile range
iqrVolatileAcid = quartileVolatileAcid75 - quartileVolatileAcid25
print("Interquartile range nilai volatile acidity adalah", iqrVolatileAcid)

# skewness
skewVolatileAcid = df['volatile acidity'].skew()
print("Skewness nilai volatile acidity adalah", skewVolatileAcid)

# kurtosis
kurtVolatileAcid = df['volatile acidity'].kurt()
print("Kurtosis nilai volatile acidity adalah", kurtVolatileAcid)
# Out:
# Rata-rata nilai volatile acidity adalah 0.5208385000000001
# Median nilai volatile acidity adalah 0.52485
# Modus nilai volatile acidity adalah 0    0.5546
# Name: volatile acidity, dtype: float64
# Standar deviasi nilai volatile acidity adalah 0.09584827405534951
# Variansi nilai volatile acidity adalah 0.009186891639389388
# Range nilai volatile acidity adalah 0.6652
# Nilai minimum volatile acidity adalah 0.1399
# Nilai maximum volatile acidity adalah 0.8051
# Kuartil nilai volatile acidity:
#      1. Kuartil 25% adalah 0.4561
#      2. Kuartil 50% adalah 0.52485
#      3. Kuartil 75% adalah 0.585375
# Interquartile range nilai volatile acidity adalah 0.12927499999999997
# Skewness nilai volatile acidity adalah -0.1976986986092083
# Kurtosis nilai volatile acidity adalah 0.16185290336961788

# %% [markdown]
# # Citric Acid

# %%
# mean
meanCitricAcid = df['citric acid'].mean()
print("Rata-rata nilai citric acid adalah", meanCitricAcid)

# median
medianCitricAcid = df['citric acid'].median()
print("Median nilai citric acid adalah", medianCitricAcid)

#modus
modusCitricAcid = df['citric acid'].mode()
print("Modus nilai citric acid adalah", modusCitricAcid)

# standard deviation
stdCitricAcid = df['citric acid'].std()
print("Standar deviasi nilai citric acid adalah", stdCitricAcid)

# variance
varCitricAcid = df['citric acid'].var()
print("Variansi nilai citric acid adalah", varCitricAcid)

# range
rangeCitricAcid = df['citric acid'].max() - df['citric acid'].min()
print("Range nilai citric acid adalah", rangeCitricAcid)

# minimum
minCitricAcid = df['citric acid'].min()
print("Nilai minimum citric acid adalah", minCitricAcid)

# maximum
maxCitricAcid = df['citric acid'].max()
print("Nilai maximum citric acid adalah", maxCitricAcid)

# kuartil
quartileCitricAcid25 = df['citric acid'].quantile(0.25)
quartileCitricAcid50 = df['citric acid'].quantile(0.50)
quartileCitricAcid75 = df['citric acid'].quantile(0.75)
print("Kuartil nilai citric acid: ")
print("     1. Kuartil 25% adalah", quartileCitricAcid25)
print("     2. Kuartil 50% adalah", quartileCitricAcid50)
print("     3. Kuartil 75% adalah", quartileCitricAcid75)

# interquartile range
iqrCitricAcid = quartileCitricAcid75 - quartileCitricAcid25
print("Interquartile range nilai citric acid adalah", iqrCitricAcid)

# skewness
skewCitricAcid = df['citric acid'].skew()
print("Skewness nilai citric acid adalah", skewCitricAcid)

# kurtosis
kurtCitricAcid = df['citric acid'].kurt()
print("Kurtosis nilai citric acid adalah", kurtCitricAcid)
# Out:
# Rata-rata nilai citric acid adalah 0.27051699999999995
# Median nilai citric acid adalah 0.2722
# Modus nilai citric acid adalah 0    0.3019
# Name: citric acid, dtype: float64
# Standar deviasi nilai citric acid adalah 0.04909837147076348
# Variansi nilai citric acid adalah 0.0024106500810810814
# Range nilai citric acid adalah 0.29290000000000005
# Nilai minimum citric acid adalah 0.1167
# Nilai maximum citric acid adalah 0.4096
# Kuartil nilai citric acid:
#      1. Kuartil 25% adalah 0.2378
#      2. Kuartil 50% adalah 0.2722
#      3. Kuartil 75% adalah 0.302325
# Interquartile range nilai citric acid adalah 0.064525
# Skewness nilai citric acid adalah -0.045576058685017296
# Kurtosis nilai citric acid adalah -0.1046792495951605

# %% [markdown]
# # Residual Sugar

# %%
# mean
meanResidualSugar = df['residual sugar'].mean()
print("Rata-rata nilai residual sugar adalah", meanResidualSugar)

# median
medianResidualSugar = df['residual sugar'].median()
print("Median nilai residual sugar adalah", medianResidualSugar)

#modus
modusResidualSugar = df['residual sugar'].mode() #masih salah
print("Modus nilai residual sugar adalah", modusResidualSugar)

# standard deviation
stdResidualSugar = df['residual sugar'].std()
print("Standar deviasi nilai residual sugar adalah", stdResidualSugar)

# variance
varResidualSugar = df['residual sugar'].var()
print("Variansi nilai residual sugar adalah", varResidualSugar)

# range
rangeResidualSugar = df['residual sugar'].max() - df['residual sugar'].min()
print("Range nilai residual sugar adalah", rangeResidualSugar)

# minimum
minResidualSugar = df['residual sugar'].min()
print("Nilai minimum residual sugar adalah", minResidualSugar)

# maximum
maxResidualSugar = df['residual sugar'].max()
print("Nilai maximum residual sugar adalah", maxResidualSugar)

# kuartil
quartileResidualSugar25 = df['residual sugar'].quantile(0.25)
quartileResidualSugar50 = df['residual sugar'].quantile(0.50)
quartileResidualSugar75 = df['residual sugar'].quantile(0.75)
print("Kuartil nilai residual sugar: ")
print("     1. Kuartil 25% adalah", quartileResidualSugar25)
print("     2. Kuartil 50% adalah", quartileResidualSugar50)
print("     3. Kuartil 75% adalah", quartileResidualSugar75)

# interquartile range
iqrResidualSugar = quartileResidualSugar75 - quartileResidualSugar25
print("Interquartile range nilai residual sugar adalah", iqrResidualSugar)

# skewness
skewResidualSugar = df['residual sugar'].skew()
print("Skewness nilai residual sugar adalah", skewResidualSugar)

# kurtosis
kurtResidualSugar = df['residual sugar'].kurt()
print("Kurtosis nilai residual sugar adalah", kurtResidualSugar)
# Out:
# Rata-rata nilai residual sugar adalah 2.5671036825067595
# Median nilai residual sugar adalah 2.519430272865794
# Modus nilai residual sugar adalah 0      0.032555
# 1      0.033333
# 2      0.051774
# 3      0.077156
# 4      0.084744
#          ...
# 995    5.210260
# 996    5.217429
# 997    5.252864
# 998    5.299524
# 999    5.550755
# Name: residual sugar, Length: 1000, dtype: float64
# Standar deviasi nilai residual sugar adalah 0.9879154365046929
# Variansi nilai residual sugar adalah 0.9759769096842579
# Range nilai residual sugar adalah 5.5182004097078625
# Nilai minimum residual sugar adalah 0.032554525015195
# Nilai maximum residual sugar adalah 5.550754934723058
# Kuartil nilai residual sugar:
#      1. Kuartil 25% adalah 1.896329943488683
#      2. Kuartil 50% adalah 2.519430272865794
#      3. Kuartil 75% adalah 3.220873482829786
# Interquartile range nilai residual sugar adalah 1.3245435393411031
# Skewness nilai residual sugar adalah 0.13263808618992312
# ...

# %% [markdown]
# # Chlorides

# %%
# mean
meanChlorides = df['chlorides'].mean()
print("Rata-rata nilai chlorides adalah", meanChlorides)

# median
medianChlorides = df['chlorides'].median()
print("Median nilai chlorides adalah", medianChlorides)

#modus
modusChlorides = df['chlorides'].mode() #masih salah
print("Modus nilai chlorides adalah", modusChlorides)

# standard deviation
stdChlorides = df['chlorides'].std()
print("Standar deviasi nilai chlorides adalah", stdChlorides)

# variance
varChlorides = df['chlorides'].var()
print("Variansi nilai chlorides adalah", varChlorides)

# range
rangeChlorides = df['chlorides'].max() - df['chlorides'].min()
print("Range nilai chlorides adalah", rangeChlorides)

# minimum
minChlorides = df['chlorides'].min()
print("Nilai minimum chlorides adalah", minChlorides)

# maximum
maxChlorides = df['chlorides'].max()
print("Nilai maximum chlorides adalah", maxChlorides)

# kuartil
quartileChlorides25 = df['chlorides'].quantile(0.25)
quartileChlorides50 = df['chlorides'].quantile(0.50)
quartileChlorides75 = df['chlorides'].quantile(0.75)
print("Kuartil nilai chlorides: ")
print("     1. Kuartil 25% adalah", quartileChlorides25)
print("     2. Kuartil 50% adalah", quartileChlorides50)
print("     3. Kuartil 75% adalah", quartileChlorides75)

# interquartile range
iqrChlorides = quartileChlorides75 - quartileChlorides25
print("Interquartile range nilai chlorides adalah", iqrChlorides)

# skewness
skewChlorides = df['chlorides'].skew()
print("Skewness nilai chlorides adalah", skewChlorides)

# kurtosis
kurtChlorides = df['chlorides'].kurt()
print("Kurtosis nilai chlorides adalah", kurtChlorides)
# Out:
# Rata-rata nilai chlorides adalah 0.08119515250784977
# Median nilai chlorides adalah 0.0821669021645236
# Modus nilai chlorides adalah 0      0.015122
# 1      0.020794
# 2      0.024259
# 3      0.027209
# 4      0.032111
#          ...
# 995    0.131425
# 996    0.133656
# 997    0.135368
# 998    0.135790
# 999    0.140758
# Name: chlorides, Length: 1000, dtype: float64
# Standar deviasi nilai chlorides adalah 0.020110647243996742
# Variansi nilai chlorides adalah 0.00040443813257247374
# Range nilai chlorides adalah 0.1256351302653488
# Nilai minimum chlorides adalah 0.0151224391657095
# Nilai maximum chlorides adalah 0.1407575694310583
# Kuartil nilai chlorides:
#      1. Kuartil 25% adalah 0.06657363190977357
#      2. Kuartil 50% adalah 0.0821669021645236
#      3. Kuartil 75% adalah 0.09531150148556258
# Interquartile range nilai chlorides adalah 0.028737869575789013
# Skewness nilai chlorides adalah -0.05131929742072573
# Kurtosis nilai chlorides adalah -0.2465081359240382

# %% [markdown]
# # Free Sulfur Dioxide

# %%
# mean
meanFreeSulfurDioxide = df['free sulfur dioxide'].mean()
print("Rata-rata nilai free sulfur dioxide adalah", meanFreeSulfurDioxide)

# median
medianFreeSulfurDioxide = df['free sulfur dioxide'].median()
print("Median nilai free sulfur dioxide adalah", medianFreeSulfurDioxide)

#modus
modusFreeSulfurDioxide = df['free sulfur dioxide'].mode() #masih salah
print("Modus nilai free sulfur dioxide adalah", modusFreeSulfurDioxide)

# standard deviation
stdFreeSulfurDioxide = df['free sulfur dioxide'].std()
print("Standar deviasi nilai free sulfur dioxide adalah", stdFreeSulfurDioxide)

# variance
varFreeSulfurDioxide = df['free sulfur dioxide'].var()
print("Variansi nilai free sulfur dioxide adalah", varFreeSulfurDioxide)

# range
rangeFreeSulfurDioxide = df['free sulfur dioxide'].max() - df['free sulfur dioxide'].min()
print("Range nilai free sulfur dioxide adalah", rangeFreeSulfurDioxide)

# minimum
minFreeSulfurDioxide = df['free sulfur dioxide'].min()
print("Nilai minimum free sulfur dioxide adalah", minFreeSulfurDioxide)

# maximum
maxFreeSulfurDioxide = df['free sulfur dioxide'].max()
print("Nilai maximum free sulfur dioxide adalah", maxFreeSulfurDioxide)

# kuartil
quartileFreeSulfurDioxide25 = df['free sulfur dioxide'].quantile(0.25)
quartileFreeSulfurDioxide50 = df['free sulfur dioxide'].quantile(0.50)
quartileFreeSulfurDioxide75 = df['free sulfur dioxide'].quantile(0.75)
print("Kuartil nilai free sulfur dioxide: ")
print("     1. Kuartil 25% adalah", quartileFreeSulfurDioxide25)
print("     2. Kuartil 50% adalah", quartileFreeSulfurDioxide50)
print("     3. Kuartil 75% adalah", quartileFreeSulfurDioxide75)

# interquartile range
iqrFreeSulfurDioxide = quartileFreeSulfurDioxide75 - quartileFreeSulfurDioxide25
print("Interquartile range nilai free sulfur dioxide adalah", iqrFreeSulfurDioxide)

# skewness
skewFreeSulfurDioxide = df['free sulfur dioxide'].skew()
print("Skewness nilai free sulfur dioxide adalah", skewFreeSulfurDioxide)

# kurtosis
kurtFreeSulfurDioxide = df['free sulfur dioxide'].kurt()
print("Kurtosis nilai free sulfur dioxide adalah", kurtFreeSulfurDioxide)
# Out:
# Rata-rata nilai free sulfur dioxide adalah 14.907679251029796
# Median nilai free sulfur dioxide adalah 14.860346236568924
# Modus nilai free sulfur dioxide adalah 0       0.194679
# 1       0.621628
# 2       0.860177
# 3       3.032139
# 4       3.129885
#          ...
# 995    26.630490
# 996    26.665773
# 997    26.822626
# 998    27.006307
# 999    27.462525
# Name: free sulfur dioxide, Length: 1000, dtype: float64
# Standar deviasi nilai free sulfur dioxide adalah 4.888099705756562
# Variansi nilai free sulfur dioxide adalah 23.893518733417388
# Range nilai free sulfur dioxide adalah 27.26784690109891
# Nilai minimum free sulfur dioxide adalah 0.194678523326937
# Nilai maximum free sulfur dioxide adalah 27.462525424425845
# Kuartil nilai free sulfur dioxide:
#      1. Kuartil 25% adalah 11.426716949457617
#      2. Kuartil 50% adalah 14.860346236568924
#      3. Kuartil 75% adalah 18.313097915395005
# Interquartile range nilai free sulfur dioxide adalah 6.886380965937388
# ...

# %% [markdown]
# # Total Sulfur Dioxide

# %%
#  mean
meanTotalSulfurDioxide = df['total sulfur dioxide'].mean()
print("Rata-rata nilai total sulfur dioxide adalah", meanTotalSulfurDioxide)

# median
medianTotalSulfurDioxide = df['total sulfur dioxide'].median()
print("Median nilai total sulfur dioxide adalah", medianTotalSulfurDioxide)

#modus
modusTotalSulfurDioxide = df['total sulfur dioxide'].mode() 
print("Modus nilai total sulfur dioxide adalah", modusTotalSulfurDioxide)

# standard deviation
stdTotalSulfurDioxide = df['total sulfur dioxide'].std()
print("Standar deviasi nilai total sulfur dioxide adalah", stdTotalSulfurDioxide)

# variance
varTotalSulfurDioxide = df['total sulfur dioxide'].var()
print("Variansi nilai total sulfur dioxide adalah", varTotalSulfurDioxide)

# range
rangeTotalSulfurDioxide = df['total sulfur dioxide'].max() - df['total sulfur dioxide'].min()
print("Range nilai total sulfur dioxide adalah", rangeTotalSulfurDioxide)

# minimum
minTotalSulfurDioxide = df['total sulfur dioxide'].min()
print("Nilai minimum total sulfur dioxide adalah", minTotalSulfurDioxide)

# maximum
maxTotalSulfurDioxide = df['total sulfur dioxide'].max()
print("Nilai maximum total sulfur dioxide adalah", maxTotalSulfurDioxide)

# kuartil
quartileTotalSulfurDioxide25 = df['total sulfur dioxide'].quantile(0.25)
quartileTotalSulfurDioxide50 = df['total sulfur dioxide'].quantile(0.50)
quartileTotalSulfurDioxide75 = df['total sulfur dioxide'].quantile(0.75)
print("Kuartil nilai total sulfur dioxide: ")
print("     1. Kuartil 25% adalah", quartileTotalSulfurDioxide25)
print("     2. Kuartil 50% adalah", quartileTotalSulfurDioxide50)
print("     3. Kuartil 75% adalah", quartileTotalSulfurDioxide75)

# interquartile range
iqrTotalSulfurDioxide = quartileTotalSulfurDioxide75 - quartileTotalSulfurDioxide25
print("Interquartile range nilai total sulfur dioxide adalah", iqrTotalSulfurDioxide)

# skewness
skewTotalSulfurDioxide = df['total sulfur dioxide'].skew()
print("Skewness nilai total sulfur dioxide adalah", skewTotalSulfurDioxide)

# kurtosis
kurtTotalSulfurDioxide = df['total sulfur dioxide'].kurt()
print("Kurtosis nilai total sulfur dioxide adalah", kurtTotalSulfurDioxide)
# Out:
# Rata-rata nilai total sulfur dioxide adalah 40.290150000000004
# Median nilai total sulfur dioxide adalah 40.19
# Modus nilai total sulfur dioxide adalah 0    35.20
# 1    37.25
# 2    39.64
# 3    40.61
# 4    41.05
# 5    41.59
# 6    44.51
# Name: total sulfur dioxide, dtype: float64
# Standar deviasi nilai total sulfur dioxide adalah 9.965767376218295
# Variansi nilai total sulfur dioxide adalah 99.3165193968969
# Range nilai total sulfur dioxide adalah 66.80999999999999
# Nilai minimum total sulfur dioxide adalah 3.15
# Nilai maximum total sulfur dioxide adalah 69.96
# Kuartil nilai total sulfur dioxide:
#      1. Kuartil 25% adalah 33.785
#      2. Kuartil 50% adalah 40.19
#      3. Kuartil 75% adalah 47.0225
# Interquartile range nilai total sulfur dioxide adalah 13.237500000000004
# Skewness nilai total sulfur dioxide adalah -0.024060026812269975
# Kurtosis nilai total sulfur dioxide adalah 0.06394978916172311

# %% [markdown]
# # Density

# %%
# mean
meanDensity = df['density'].mean()
print("Rata-rata nilai density adalah", meanDensity)

# median
medianDensity = df['density'].median()
print("Median nilai density adalah", medianDensity)

#modus
modusDensity = df['density'].mode()
print("Modus nilai density adalah", modusDensity)

# standard deviation
stdDensity = df['density'].std()
print("Standar deviasi nilai density adalah", stdDensity)

# variance
varDensity = df['density'].var()
print("Variansi nilai density adalah", varDensity)

# range
rangeDensity = df['density'].max() - df['density'].min()
print("Range nilai density adalah", rangeDensity)

# minimum
minDensity = df['density'].min()
print("Nilai minimum density adalah", minDensity)

# maximum
maxDensity = df['density'].max()
print("Nilai maximum density adalah", maxDensity)

# kuartil
quartileDensity25 = df['density'].quantile(0.25)
quartileDensity50 = df['density'].quantile(0.50)
quartileDensity75 = df['density'].quantile(0.75)
print("Kuartil nilai density: ")
print("     1. Kuartil 25% adalah", quartileDensity25)
print("     2. Kuartil 50% adalah", quartileDensity50)
print("     3. Kuartil 75% adalah", quartileDensity75)

# interquartile range
iqrDensity = quartileDensity75 - quartileDensity25
print("Interquartile range nilai density adalah", iqrDensity)

# skewness
skewDensity = df['density'].skew()
print("Skewness nilai density adalah", skewDensity)

# kurtosis
kurtDensity = df['density'].kurt()
print("Kurtosis nilai density adalah", kurtDensity)
# Out:
# Rata-rata nilai density adalah 0.9959253000000001
# Median nilai density adalah 0.996
# Modus nilai density adalah 0    0.9959
# 1    0.9961
# 2    0.9965
# 3    0.9970
# Name: density, dtype: float64
# Standar deviasi nilai density adalah 0.0020201809426487133
# Variansi nilai density adalah 4.081131041041045e-06
# Range nilai density adalah 0.013799999999999923
# Nilai minimum density adalah 0.9888
# Nilai maximum density adalah 1.0026
# Kuartil nilai density:
#      1. Kuartil 25% adalah 0.9946
#      2. Kuartil 50% adalah 0.996
#      3. Kuartil 75% adalah 0.9972
# Interquartile range nilai density adalah 0.0025999999999999357
# Skewness nilai density adalah -0.07688278915513917
# Kurtosis nilai density adalah 0.01636562128503849

# %% [markdown]
# # pH

# %%
# mean
meanpH = df['pH'].mean()
print("Rata-rata nilai pH adalah", meanpH)

# median
medianpH = df['pH'].median()
print("Median nilai pH adalah", medianpH)

#modus
moduspH = df['pH'].mode()
print("Modus nilai pH adalah", moduspH)

# standard deviation
stdpH = df['pH'].std()
print("Standar deviasi nilai pH adalah", stdpH)

# variance
varpH = df['pH'].var()
print("Variansi nilai pH adalah", varpH)

# range
rangepH = df['pH'].max() - df['pH'].min()
print("Range nilai pH adalah", rangepH)

# minimum
minpH = df['pH'].min()
print("Nilai minimum pH adalah", minpH)

# maximum
maxpH = df['pH'].max()
print("Nilai maximum pH adalah", maxpH)

# kuartil
quartilepH25 = df['pH'].quantile(0.25)
quartilepH50 = df['pH'].quantile(0.50)
quartilepH75 = df['pH'].quantile(0.75)
print("Kuartil nilai pH: ")
print("     1. Kuartil 25% adalah", quartilepH25)
print("     2. Kuartil 50% adalah", quartilepH50)
print("     3. Kuartil 75% adalah", quartilepH75)

# interquartile range
iqrpH = quartilepH75 - quartilepH25
print("Interquartile range nilai pH adalah", iqrpH)

# skewness
skewpH = df['pH'].skew()
print("Skewness nilai pH adalah", skewpH)

# kurtosis
kurtpH = df['pH'].kurt()
print("Kurtosis nilai pH adalah", kurtpH)
# Out:
# Rata-rata nilai pH adalah 3.30361
# Median nilai pH adalah 3.3
# Modus nilai pH adalah 0    3.34
# Name: pH, dtype: float64
# Standar deviasi nilai pH adalah 0.10487548220040166
# Variansi nilai pH adalah 0.010998866766766766
# Range nilai pH adalah 0.7399999999999998
# Nilai minimum pH adalah 2.97
# Nilai maximum pH adalah 3.71
# Kuartil nilai pH:
#      1. Kuartil 25% adalah 3.23
#      2. Kuartil 50% adalah 3.3
#      3. Kuartil 75% adalah 3.37
# Interquartile range nilai pH adalah 0.14000000000000012
# Skewness nilai pH adalah 0.14767259510827038
# Kurtosis nilai pH adalah 0.0809095518741838

# %% [markdown]
# # Sulphates

# %%
# mean
meanSulphates = df['sulphates'].mean()
print("Rata-rata nilai sulphates adalah", meanSulphates)

# median
medianSulphates = df['sulphates'].median()
print("Median nilai sulphates adalah", medianSulphates)

#modus
modusSulphates = df['sulphates'].mode()
print("Modus nilai sulphates adalah", modusSulphates)

# standard deviation
stdSulphates = df['sulphates'].std()
print("Standar deviasi nilai sulphates adalah", stdSulphates)

# variance
varSulphates = df['sulphates'].var()
print("Variansi nilai sulphates adalah", varSulphates)

# range
rangeSulphates = df['sulphates'].max() - df['sulphates'].min()
print("Range nilai sulphates adalah", rangeSulphates)

# minimum
minSulphates = df['sulphates'].min()
print("Nilai minimum sulphates adalah", minSulphates)

# maximum
maxSulphates = df['sulphates'].max()
print("Nilai maximum sulphates adalah", maxSulphates)

# kuartil
quartileSulphates25 = df['sulphates'].quantile(0.25)
quartileSulphates50 = df['sulphates'].quantile(0.50)
quartileSulphates75 = df['sulphates'].quantile(0.75)
print("Kuartil nilai sulphates: ")
print("     1. Kuartil 25% adalah", quartileSulphates25)
print("     2. Kuartil 50% adalah", quartileSulphates50)
print("     3. Kuartil 75% adalah", quartileSulphates75)

# interquartile range
iqrSulphates = quartileSulphates75 - quartileSulphates25
print("Interquartile range nilai sulphates adalah", iqrSulphates)

# skewness
skewSulphates = df['sulphates'].skew()
print("Skewness nilai sulphates adalah", skewSulphates)

# kurtosis
kurtSulphates = df['sulphates'].kurt()
print("Kurtosis nilai sulphates adalah", kurtSulphates)
# Out:
# Rata-rata nilai sulphates adalah 0.5983899999999999
# Median nilai sulphates adalah 0.595
# Modus nilai sulphates adalah 0    0.59
# Name: sulphates, dtype: float64
# Standar deviasi nilai sulphates adalah 0.10081900799141187
# Variansi nilai sulphates adalah 0.010164472372372372
# Range nilai sulphates adalah 0.6699999999999999
# Nilai minimum sulphates adalah 0.29
# Nilai maximum sulphates adalah 0.96
# Kuartil nilai sulphates:
#      1. Kuartil 25% adalah 0.53
#      2. Kuartil 50% adalah 0.595
#      3. Kuartil 75% adalah 0.67
# Interquartile range nilai sulphates adalah 0.14
# Skewness nilai sulphates adalah 0.1491989008699043
# Kurtosis nilai sulphates adalah 0.06481928180859686

# %% [markdown]
# # Alcohol

# %%
# mean
meanAlcohol = df['alcohol'].mean()
print("Rata-rata nilai alcohol adalah", meanAlcohol)

# median
medianAlcohol = df['alcohol'].median()
print("Median nilai alcohol adalah", medianAlcohol)

#modus
modusAlcohol = df['alcohol'].mode()
print("Modus nilai alcohol adalah", modusAlcohol)

# standard deviation
stdAlcohol = df['alcohol'].std()
print("Standar deviasi nilai alcohol adalah", stdAlcohol)

# variance
varAlcohol = df['alcohol'].var()
print("Variansi nilai alcohol adalah", varAlcohol)

# range
rangeAlcohol = df['alcohol'].max() - df['alcohol'].min()
print("Range nilai alcohol adalah", rangeAlcohol)

# minimum
minAlcohol = df['alcohol'].min()
print("Nilai minimum alcohol adalah", minAlcohol)

# maximum
maxAlcohol = df['alcohol'].max()
print("Nilai maximum alcohol adalah", maxAlcohol)

# kuartil
quartileAlcohol25 = df['alcohol'].quantile(0.25)
quartileAlcohol50 = df['alcohol'].quantile(0.50)
quartileAlcohol75 = df['alcohol'].quantile(0.75)
print("Kuartil nilai alcohol: ")
print("     1. Kuartil 25% adalah", quartileAlcohol25)
print("     2. Kuartil 50% adalah", quartileAlcohol50)
print("     3. Kuartil 75% adalah", quartileAlcohol75)

# interquartile range
iqrAlcohol = quartileAlcohol75 - quartileAlcohol25
print("Interquartile range nilai alcohol adalah", iqrAlcohol)

# skewness
skewAlcohol = df['alcohol'].skew()
print("Skewness nilai alcohol adalah", skewAlcohol)

# kurtosis
kurtAlcohol = df['alcohol'].kurt()
print("Kurtosis nilai alcohol adalah", kurtAlcohol)
# Out:
# Rata-rata nilai alcohol adalah 10.592279999999999
# Median nilai alcohol adalah 10.61
# Modus nilai alcohol adalah 0     9.86
# 1    10.31
# Name: alcohol, dtype: float64
# Standar deviasi nilai alcohol adalah 1.5107060052287586
# Variansi nilai alcohol adalah 2.282232634234234
# Range nilai alcohol adalah 8.989999999999998
# Nilai minimum alcohol adalah 6.03
# Nilai maximum alcohol adalah 15.02
# Kuartil nilai alcohol:
#      1. Kuartil 25% adalah 9.56
#      2. Kuartil 50% adalah 10.61
#      3. Kuartil 75% adalah 11.622499999999999
# Interquartile range nilai alcohol adalah 2.0624999999999982
# Skewness nilai alcohol adalah -0.01899140432111647
# Kurtosis nilai alcohol adalah -0.13173155932281988

# %% [markdown]
# # Quality

# %%
# mean
meanQuality = df['quality'].mean()
print("Rata-rata nilai quality adalah", meanQuality)

# median
medianQuality = df['quality'].median()
print("Median nilai quality adalah", medianQuality)

#modus
modusQuality = df['quality'].mode()
print("Modus nilai quality adalah", modusQuality)

# standard deviation
stdQuality = df['quality'].std()
print("Standar deviasi nilai quality adalah", stdQuality)

# variance
varQuality = df['quality'].var()
print("Variansi nilai quality adalah", varQuality)

# range
rangeQuality = df['quality'].max() - df['quality'].min()
print("Range nilai quality adalah", rangeQuality)

# minimum
minQuality = df['quality'].min()
print("Nilai minimum quality adalah", minQuality)

# maximum
maxQuality = df['quality'].max()
print("Nilai maximum quality adalah", maxQuality)

# kuartil
quartileQuality25 = df['quality'].quantile(0.25)
quartileQuality50 = df['quality'].quantile(0.50)
quartileQuality75 = df['quality'].quantile(0.75)
print("Kuartil nilai quality: ")
print("     1. Kuartil 25% adalah", quartileQuality25)
print("     2. Kuartil 50% adalah", quartileQuality50)
print("     3. Kuartil 75% adalah", quartileQuality75)

# interquartile range
iqrQuality = quartileQuality75 - quartileQuality25
print("Interquartile range nilai quality adalah", iqrQuality)

# skewness
skewQuality = df['quality'].skew()
print("Skewness nilai quality adalah", skewQuality)

# kurtosis
kurtQuality = df['quality'].kurt()
print("Kurtosis nilai quality adalah", kurtQuality)

# %% [markdown]
# # No 2
# Membuat Visualisasi plot distribusi, dalam bentuk histogram dan boxplot untuk setiap
# kolom numerik. Berikan uraian penjelasan kondisi setiap kolom berdasarkan kedua plot
# tersebut.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

df = pd.read_csv('anggur.csv')
df
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             5.90            0.4451       0.1813        2.049401   0.070574
# 1             8.40            0.5768       0.2099        3.109590   0.101681
# 2             7.54            0.5918       0.3248        3.673744   0.072416
# 3             5.39            0.4201       0.3131        3.371815   0.072755
# 4             6.51            0.5675       0.1940        4.404723   0.066379
# ..             ...               ...          ...             ...        ...
# 995           7.96            0.6046       0.2662        1.592048   0.057555
# 996           8.48            0.4080       0.2227        0.681955   0.051627
# 997           6.11            0.4841       0.3720        2.377267   0.042806
# 998           7.76            0.3590       0.3208        4.294486   0.098276
# 999           5.87            0.5214       0.1883        2.179490   0.052923
#
# ...

# %% [markdown]
# # Fixed Acidity

# %%
df.hist(column = 'fixed acidity', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
# give title
plt.title('Histogram of Fixed Acidity')
# give xlabel
plt.xlabel('Fixed Acidity')
# give ylabel
plt.ylabel('Frequency')
# show plot
plt.show()

# %%
df.boxplot(column='fixed acidity', figsize = (12,6), meanline = True, showmeans = True)
# give title
plt.title('Boxplot of Fixed Acidity')
# give ylabel
plt.ylabel('Frequency')
# show plot
plt.show()

# %% [markdown]
# # Volatile Acidity

# %%
df.hist(column = 'volatile acidity', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
plt.title('Histogram of Volatile Acidity')
plt.xlabel('Volatile Acidity')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='volatile acidity', figsize = (12,6), meanline = True, showmeans = True)
# give title
plt.title('Boxplot of Volatile Acidity')
# give ylabel
plt.ylabel('Frequency')
# show plot
plt.show()

# %% [markdown]
# # Citric Acid

# %%
df.hist(column = 'citric acid', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
plt.title('Histogram of Citric Acid')
plt.xlabel('Citric Acid')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='citric acid', figsize = (12,6), meanline = True, showmeans = True)
plt.title('Boxplot of Citric Acid')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Residual Sugar

# %%
df.hist(column = 'residual sugar', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
plt.title('Histogram of Residual Sugar')
plt.xlabel('Residual Sugar')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='residual sugar', figsize = (12,6), meanline = True, showmeans = True)
plt.title('Boxplot of Residual Sugar')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Chlorides

# %%
df.hist(column = 'chlorides', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
plt.title('Histogram of Chlorides')
plt.xlabel('Chlorides')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='chlorides', figsize = (12,6), meanline = True, showmeans = True)
# give title
plt.title('Boxplot of Chlorides')
# give ylabel
plt.ylabel('Frequency')
# show plot
plt.show()

# %% [markdown]
# # Free Sulfur Dioxide

# %%
df.hist(column = 'free sulfur dioxide', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
plt.title('Histogram of Free Sulfur Dioxide')
plt.xlabel('Free Sulfur Dioxide')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='free sulfur dioxide', figsize = (12,6), meanline = True, showmeans = True)
# give title
plt.title('Boxplot of Free of Sulfur Dioxide')
# give ylabel
plt.ylabel('Frequency')
# show plot
plt.show()

# %% [markdown]
# # Total Sulfur Dioxide

# %%
df.hist(column = 'total sulfur dioxide', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
plt.title('Histogram of Total Sulfur Dioxide')
plt.xlabel('Total Sulfur Dioxide')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='total sulfur dioxide', figsize = (12,6), meanline = True, showmeans = True)
# give title
plt.title('Boxplot of Total Sulfur Dioxide')
# give ylabel
plt.ylabel('Frequency')
# show plot
plt.show()
