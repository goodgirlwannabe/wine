# %% [markdown]
# # No 2
# Membuat Visualisasi plot distribusi, dalam bentuk histogram dan boxplot untuk setiap
# kolom numerik. Berikan uraian penjelasan kondisi setiap kolom berdasarkan kedua plot
# tersebut.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

df = pd.read_csv('anggur.csv')
df
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             5.90            0.4451       0.1813        2.049401   0.070574
# 1             8.40            0.5768       0.2099        3.109590   0.101681
# 2             7.54            0.5918       0.3248        3.673744   0.072416
# 3             5.39            0.4201       0.3131        3.371815   0.072755
# 4             6.51            0.5675       0.1940        4.404723   0.066379
# ..             ...               ...          ...             ...        ...
# 995           7.96            0.6046       0.2662        1.592048   0.057555
# 996           8.48            0.4080       0.2227        0.681955   0.051627
# 997           6.11            0.4841       0.3720        2.377267   0.042806
# 998           7.76            0.3590       0.3208        4.294486   0.098276
# 999           5.87            0.5214       0.1883        2.179490   0.052923
#
# ...

# %% [markdown]
# # Fixed Acidity

# %%
df.hist(column = 'fixed acidity', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
# give title
plt.title('Histogram of Fixed Acidity')
# give xlabel
plt.xlabel('Fixed Acidity')
# give ylabel
plt.ylabel('Frequency')
# show plot
plt.show()

# %%
df.boxplot(column='fixed acidity', figsize = (12,6), meanline = True, showmeans = True)
# give title
plt.title('Boxplot of Fixed Acidity')
# give ylabel
plt.ylabel('Frequency')
# show plot
plt.show()

# %% [markdown]
# Histogram tersebut menunjukkan bahwa distribusi fixed acidity terlihat condong ke arah kanan (positively skewed). Selain itu, boxplot menunjukkan bahwa terdapat beberapa data outlier yang berada di rentang 3-4 dan 10-12 dan median terlihat di sekitar 7.1, dengan kuartil pertama sekitar 6.3 dan kuartil ketiga tepat di 8, serta nilai minimum di sekitar 3.3 dan nilai maksimum berada pada sekitar 11.5

# %% [markdown]
# # Volatile Acidity

# %%
df.hist(column = 'volatile acidity', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
plt.title('Histogram of Volatile Acidity')
plt.xlabel('Volatile Acidity')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='volatile acidity', figsize = (12,6), meanline = True, showmeans = True)
# give title
plt.title('Boxplot of Volatile Acidity')
# give ylabel
plt.ylabel('Frequency')
# show plot
plt.show()

# %% [markdown]
# Histogram tersebut menunjukkan bahwa distribusi volatile acidity terlihat condong ke arah kiri (negatively skewed). Selain itu, boxplot menunjukkan bahwa terdapat beberapa data outlier yang berada di rentang 0-0.27 dan 0.8 dan median terlihat di sekitar 0.52, dengan kuartil pertama sekitar 0.45 dan kuartil ketiga di sekitar 0.58, serta nilai minimum di sekitar 0.1 dan nilai maksimum berada pada sekitar 0.8

# %% [markdown]
# # Citric Acid

# %%
df.hist(column = 'citric acid', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
plt.title('Histogram of Citric Acid')
plt.xlabel('Citric Acid')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='citric acid', figsize = (12,6), meanline = True, showmeans = True)
plt.title('Boxplot of Citric Acid')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Histogram tersebut menunjukkan bahwa distribusi citric acid terlihat condong ke arah kiri (negatively skewed). Selain itu, boxplot menunjukkan bahwa terdapat beberapa data outlier yang berada di rentang 0-0.15 dan 0.39-0.43 dan median terlihat di sekitar 0.27, dengan kuartil pertama sekitar 0.23 dan kuartil ketiga di sektar 0.3, serta nilai minimum di sekitar 0.11 dan nilai maksimum berada pada sekitar 0.41

# %% [markdown]
# # Residual Sugar

# %%
df.hist(column = 'residual sugar', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
plt.title('Histogram of Residual Sugar')
plt.xlabel('Residual Sugar')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='residual sugar', figsize = (12,6), meanline = True, showmeans = True)
plt.title('Boxplot of Residual Sugar')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Histogram tersebut menunjukkan bahwa distribusi residual sugar terlihat condong ke arah kanan (positively skewed). Selain itu, boxplot menunjukkan bahwa hanya terdapat outlier yang lebih besar dari maksimum di rentang 5-6 dan median terlihat di sekitar 2.5, dengan kuartil pertama sekitar 1.9 dan kuartil ketiga sekitar 3.2, serta nilai minimum di sekitar 0 dan nilai maksimum berada pada sekitar 5.5

# %% [markdown]
# # Chlorides

# %%
df.hist(column = 'chlorides', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
plt.title('Histogram of Chlorides')
plt.xlabel('Chlorides')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='chlorides', figsize = (12,6), meanline = True, showmeans = True)
# give title
plt.title('Boxplot of Chlorides')
# give ylabel
plt.ylabel('Frequency')
# show plot
plt.show()

# %% [markdown]
# Histogram tersebut menunjukkan bahwa distribusi chlorides terlihat condong ke arah kiri (negatively skewed). Selain itu, boxplot menunjukkan bahwa terdapat beberapa data outlier yang berada di rentang 0-0.02 dan 0.13-0.14 dan median terlihat di sekitar 0.08, dengan kuartil pertama sekitar 0.065 dan kuartil ketiga di sekitar 0.09, serta nilai minimum di sekitar 0.01 dan nilai maksimum berada pada sekitar 0.14

# %% [markdown]
# # Free Sulfur Dioxide

# %%
df.hist(column = 'free sulfur dioxide', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
plt.title('Histogram of Free Sulfur Dioxide')
plt.xlabel('Free Sulfur Dioxide')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='free sulfur dioxide', figsize = (12,6), meanline = True, showmeans = True)
# give title
plt.title('Boxplot of Free of Sulfur Dioxide')
# give ylabel
plt.ylabel('Frequency')
# show plot
plt.show()

# %% [markdown]
# Histogram tersebut menunjukkan bahwa distribusi free sulfur dioxide terlihat condong ke arah kiri (negatively skewed). Selain itu, boxplot menunjukkan bahwa hanya terdapat outlier yang lebih kecil dari minimum pada rentang 0-4 dan median terlihat di sekitar 15, dengan kuartil pertama sekitar 11 dan kuartil ketiga sekitar 18, serta nilai minimum di sekitar 0 dan nilai maksimum berada pada sekitar 27

# %% [markdown]
# # Total Sulfur Dioxide

# %%
df.hist(column = 'total sulfur dioxide', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
plt.title('Histogram of Total Sulfur Dioxide')
plt.xlabel('Total Sulfur Dioxide')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='total sulfur dioxide', figsize = (12,6), meanline = True, showmeans = True)
# give title
plt.title('Boxplot of Total Sulfur Dioxide')
# give ylabel
plt.ylabel('Frequency')
# show plot
plt.show()

# %% [markdown]
# Histogram tersebut menunjukkan bahwa distribusi total sulfur dioxide terlihat condong ke arah kiri (negatively skewed). Selain itu, boxplot menunjukkan bahwa terdapat beberapa data outlier yang berada di rentang 0-15 dan 65-70 dan median terlihat di sekitar 40, dengan kuartil pertama sekitar 33 dan kuartil ketiga sekitar 487, serta nilai minimum di sekitar 3 dan nilai maksimum berada pada sekitar 69

# %% [markdown]
# # Density

# %%
df.hist(column = 'density', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
plt.title('Histogram of Density')
plt.xlabel('Density')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='density', figsize = (12,6), meanline = True, showmeans = True)
# give title
plt.title('Boxplot of Density')
# give ylabel
plt.ylabel('Frequency')
# show plot
plt.show()

# %% [markdown]
# Histogram tersebut menunjukkan bahwa distribusi density terlihat condong ke arah kiri (negatively skewed). Selain itu, boxplot menunjukkan bahwa terdapat beberapa data outlier yang berada di rentang 0.988-0.991 dan 1.001-1.003 dan median terlihat di sekitar 0.996, dengan kuartil pertama sekitar 0.994 dan kuartil ketiga sekitar 0.997, serta nilai minimum di sekitar 0.988 dan nilai maksimum berada pada sekitar 1.002

# %% [markdown]
# # pH

# %%
df.hist(column = 'pH', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
plt.title('Histogram of pH')
plt.xlabel('pH')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='pH', figsize = (12,6), meanline = True, showmeans = True)
# give title
plt.title('Boxplot of pH')
# give ylabel
plt.ylabel('Frequency')
# show plot
plt.show()

# %% [markdown]
# Histogram tersebut menunjukkan bahwa distribusi pH terlihat condong ke arah kanan (positively skewed). Selain itu, boxplot menunjukkan bahwa terdapat beberapa data outlier yang berada di rentang 2.9-3.1 dan 3.6-3.8 dan median terlihat di sekitar 3.3, dengan kuartil pertama sekitar 3.23 dan kuartil ketiga sekitar 3.37, serta nilai minimum di sekitar 2.97 dan nilai maksimum berada pada sekitar 3.7

# %% [markdown]
# # Sulphates

# %%
df.hist(column = 'sulphates', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
plt.title('Histogram of Sulphates')
plt.xlabel('Sulphates')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='sulphates', figsize = (12,6), meanline = True, showmeans = True)
# give title
plt.title('Boxplot of Sulphates')
# give ylabel
plt.ylabel('Frequency')
# show plot
plt.show()

# %% [markdown]
# Histogram tersebut menunjukkan bahwa distribusi sulphates terlihat condong ke arah kanan (positively skewed). Selain itu, boxplot menunjukkan bahwa terdapat beberapa data outlier yang berada di rentang 0.2-0.3 dan 0.89-1.0 dan median terlihat di sekitar 0.6, dengan kuartil pertama sekitar 0.53 dan kuartil ketiga sekitar 0.67, serta nilai minimum di sekitar 0.29 dan nilai maksimum berada pada sekitar 0.96

# %% [markdown]
# # Alcohol

# %%
df.hist(column = 'alcohol', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
plt.title('Histogram of Alcohol')
plt.xlabel('Alcohol')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='alcohol', figsize = (12,6), meanline = True, showmeans = True)
# give title
plt.title('Boxplot of Alcohol')
# give ylabel
plt.ylabel('Frequency')
# show plot
plt.show()

# %% [markdown]
# Histogram tersebut menunjukkan bahwa distribusi alcohol terlihat tidak condong ke kanan maupun kiri (normal distribution). Selain itu, boxplot menunjukkan bahwa terdapat beberapa data outlier yang berada di rentang 6-7 dan 14-16 dan median terlihat di sekitar 10.6, dengan kuartil pertama sekitar 9.5 dan kuartil ketiga sekitar 11.6, serta nilai minimum di sekitar 6 dan nilai maksimum berada pada sekitar 15

# %% [markdown]
# # Quality

# %%
df.hist(column = 'quality', figsize = (12,6), rwidth = 0.9, bins = 10, color = '#722F37')
plt.title('Histogram of Quality')
plt.xlabel('Quality')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='quality', figsize = (12,6), meanline = True, showmeans = True)
# give title
plt.title('Boxplot of Quality')
# give ylabel
plt.ylabel('Frequency')
# show plot
plt.show()

# %% [markdown]
# Histogram tersebut menunjukkan bahwa distribusi quality terlihat condong ke arah kiri (negatively skewed). Selain itu, boxplot menunjukkan bahwa tidak terdapat data outlier dan median terlihat di sekitar 8, dengan kuartil pertama sekitar 7 dan kuartil ketiga sekitar 9, serta nilai minimum di sekitar 5 dan nilai maksimum berada pada sekitar 10
